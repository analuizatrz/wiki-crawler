# %%
import pandas as pd
feature_columns = [
                       'Section count', 'Subsection count', 'Complete URL link count', 'Complete URL link count per section',
                       'Complete URL link count per length', 'Relative URL link count', 'Relative URL link count per section',
                       'Relative URL link count per length', 'Same page link count', 'Same page link count per section',
                       'Same page link count per length', 'Mean section size', 'Mean subsection size', 'Largest section size',
                       'Shortest section size', 'Standard deviation of the section size', 'Images count', 'Images per length', 'Images per section',
                       'Images per subsection', 'Phrase count', 'Large phrase count', 'Paragraph count', 'Large paragraph count',
                       'Largest phrase size', 'Large phrase rate', 'Short phrase rate', 'Char Count', 'Word Count', 'Articles count',
                       'Auxiliary verbs count', 'Coordination conjunctions count', 'Correlative conjunctions count', 'Indefinite pronouns count',
                       'Interrogative pronouns count', 'Prepositions count', 'Pronouns count', 'Relative pronoums count',
                       'Subordinating conjunctions count', 'To be verbs count', 'Sentences starting with articles',
                       'Sentences starting with auxiliary verbs', 'Sentences starting with coordination conjunctions',
                       'Sentences starting with correlative conjunctions', 'Sentences starting with indefinite pronouns',
                       'Sentences starting with interrogative pronouns', 'Sentences starting with prepositions', 'Sentences starting with pronouns',
                       'Sentences starting with relative pronoums', 'Sentences starting with subordinating conjunctions',
                       'Sentences starting with to be verbs', 'ARI readability feature', 'Coleman-Liau readability feature',
                       'Flesch Reading Ease Readability Feature', 'Flesch Kincaid Readability Feature', 'Gunning Fog Index readability feature',
                       'Lasbarhetsindex readability feature', 'SMOG Grading readability feature'
                    ]

base_folder = "/home/ana/Documents/tcc-web-crawler/data"

filename = f"{base_folder}/5-join_multiple_class_without_C-reduced.csv"

# %%
revision_dataset = pd.read_csv(filename)

# %%
df = pd.DataFrame()

# info_columns = #['title', 'timestamp', 'access', 'category', 'pageid', 'raw_category', 'revision.anon',
                #    'revision.comment', 'revision.commenthidden', 'revision.parentid', 'revision.revid', 'revision.user']

info_columns = ['timestamp', 'access', 'category', 'raw_category', 'revision.anon', 'revision.comment', 'revision.commenthidden', 'revision.parentid', 'revision.revid', 'revision.user']

# commom_columns = ['title', 'pageid']
# row_iterator = revision_dataset.iterrows()
# _, actual = next(row_iterator)
# i, row = next(row_iterator)

def build_row(actual, past, diff_columns, info_columns, date_columns):
    row = {}
    for columns in info_columns:
        row[f"past_{columns}"] = past[columns]
        row[f"actual_{columns}"] = actual[columns]
    return row

def build_dataset(dataset, diff_columns, info_columns, date_columns):
    commom_columns = ['title', 'pageid']
    columns = commom_columns
    for column in info_columns:
        columns += [f"past_{column}",f"actual_{column}"]
    #print(columns)
    df = pd.DataFrame(columns=columns)

    row_iterator = revision_dataset.iterrows()
    _, actual = next(row_iterator)
    for i, row in row_iterator:
        if(row['title'] == actual['title']):
            new_row = build_row(actual, row, diff_columns, info_columns, date_columns)
          #  print(new_row)
            df.at[i-1,:] = new_row
            df.at[i-1,'title'] = row['title']
            df.at[i-1,'pageid'] = row['pageid']
        actual = row
            #esult.insert(0, 'title', title)
    #result.insert(0, 'pageid', list(response["query"]["pages"])[0])

    return df
#build_row(actual, row, None, info_columns, None)
result = build_dataset(revision_dataset, None, info_columns, None)
result
# Out:
#                    title pageid        past_timestamp      actual_timestamp  \
# 0          1,3-Butadiene    NaN  2008-11-03T15:00:27Z  2008-12-09T21:43:01Z
# 1          1,3-Butadiene    NaN  2008-10-08T20:43:02Z  2008-11-03T15:00:27Z
# 2          1,3-Butadiene    NaN  2008-09-04T19:51:08Z  2008-10-08T20:43:02Z
# 3          1,3-Butadiene    NaN  2008-08-20T19:39:36Z  2008-09-04T19:51:08Z
# 4          1,3-Butadiene    NaN  2008-06-30T08:22:50Z  2008-08-20T19:39:36Z
# ..                   ...    ...                   ...                   ...
# 82  1920 Palestine riots    NaN  2007-07-30T19:48:10Z  2007-07-30T19:48:10Z
# 83  1920 Palestine riots    NaN  2007-07-30T19:48:10Z  2007-07-30T19:48:10Z
# 84  1920 Palestine riots    NaN  2007-07-30T19:48:10Z  2007-07-30T19:48:10Z
# 85  1920 Palestine riots    NaN  2007-06-24T17:44:50Z  2007-07-30T19:48:10Z
# 86  1920 Palestine riots    NaN  2007-05-30T20:56:39Z  2007-06-24T17:44:50Z
#
#              past_access         actual_access past_category actual_category  \
# 0   2008-12-01T00:00:00Z  2009-01-01T00:00:00Z             b               b
# 1   2008-11-01T00:00:00Z  2008-12-01T00:00:00Z             b               b
# 2   2008-10-01T00:00:00Z  2008-11-01T00:00:00Z             b               b
# 3   2008-09-01T00:00:00Z  2008-10-01T00:00:00Z             b               b
# 4   2008-08-01T00:00:00Z  2008-09-01T00:00:00Z             b               b
# ..                   ...                   ...           ...             ...
# 82  2007-10-01T00:00:00Z  2007-11-01T00:00:00Z         start           start
# 83  2007-09-01T00:00:00Z  2007-10-01T00:00:00Z         start           start
# 84  2007-08-01T00:00:00Z  2007-09-01T00:00:00Z         start           start
# 85  2007-07-01T00:00:00Z  2007-08-01T00:00:00Z         start           start
# 86  2007-06-01T00:00:00Z  2007-07-01T00:00:00Z         start           start
#
#                       past_raw_category  \
# 0           [('class=B|', 'B', '', '')]
# 1           [('class=B|', 'B', '', '')]
# 2           [('class=B|', 'B', '', '')]
# 3           [('class=B|', 'B', '', '')]
# 4           [('class=B|', 'B', '', '')]
# ..                                  ...
# 82  [('class=Start|', 'Start', '', '')]
# 83  [('class=Start|', 'Start', '', '')]
# 84  [('class=Start|', 'Start', '', '')]
# 85  [('class=Start|', 'Start', '', '')]
# 86  [('class=Start|', 'Start', '', '')]
#
#                                   actual_raw_category  ...  \
# 0   [('class=B|', 'B', '', ''), ('class="autosigne...  ...
# 1                         [('class=B|', 'B', '', '')]  ...
# 2                         [('class=B|', 'B', '', '')]  ...
# 3                         [('class=B|', 'B', '', '')]  ...
# 4                         [('class=B|', 'B', '', '')]  ...
# ..                                                ...  ...
# 82                [('class=Start|', 'Start', '', '')]  ...
# 83                [('class=Start|', 'Start', '', '')]  ...
# 84                [('class=Start|', 'Start', '', '')]  ...
# 85                [('class=Start|', 'Start', '', '')]  ...
# 86                [('class=Start|', 'Start', '', '')]  ...
#
#                                 past_revision.comment  \
# 0   Reverted edits by [[Special:Contributions/213....
# 1                                              - fchm
# 2                                                 NaN
# 3                 /* Safety */ data are plural, style
# 4   Reverted edits by [[Special:Contributions/145....
# ..                                                ...
# 82  please work this out in Talk: Also, given the ...
# 83  please work this out in Talk: Also, given the ...
# 84  please work this out in Talk: Also, given the ...
# 85                           Restored Segev's comment
# 86   sp, date & link fixes  using [[Project:AWB|AWB]]
#
#                               actual_revision.comment  \
# 0        related compounds should have a wiki article
# 1   Reverted edits by [[Special:Contributions/213....
# 2                                              - fchm
# 3                                                 NaN
# 4                 /* Safety */ data are plural, style
# ..                                                ...
# 82  please work this out in Talk: Also, given the ...
# 83  please work this out in Talk: Also, given the ...
# 84  please work this out in Talk: Also, given the ...
# 85  please work this out in Talk: Also, given the ...
# 86                           Restored Segev's comment
#
#    past_revision.commenthidden actual_revision.commenthidden  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ..                         ...                           ...
# 82                         NaN                           NaN
# 83                         NaN                           NaN
# 84                         NaN                           NaN
# 85                         NaN                           NaN
# 86                         NaN                           NaN
#
#    past_revision.parentid actual_revision.parentid past_revision.revid  \
# 0               249411771                256733594           249411792
# 1               236301799                249411771           243984079
# 2               233170974                236301799           236301799
# 3               230579563                233170974           233170974
# 4               222618863                230579563           222618879
# ..                    ...                      ...                 ...
# 82              148111448                148111448           148111701
# 83              148111448                148111448           148111701
# 84              148111448                148111448           148111701
# 85              140329746                148111448           140341383
# 86              134278392                140329746           134653935
#
#    actual_revision.revid past_revision.user actual_revision.user
# 0              256913977           Smalljim                V8rik
# 1              249411792            Epop fr             Smalljim
# 2              243984079            Epop fr              Epop fr
# 3              236301799      86.166.233.76              Epop fr
# 4              233170974            Epbr123        86.166.233.76
# ..                   ...                ...                  ...
# 82             148111701              Jayjg                Jayjg
# 83             148111701              Jayjg                Jayjg
# 84             148111701              Jayjg                Jayjg
# 85             148111701      Ian Pitchford                Jayjg
# 86             140341383     Colonies Chris        Ian Pitchford
#
# [84 rows x 22 columns]

# %%
# poc da construção de um dataframe
df = pd.DataFrame(columns=["title","number"])
for i in range(0,19):
    oi = {"title":f"-{i}", "number":i}
    df.at[i,:] = oi
df

# %%
# poc de diferença de datas
date_start = "2009-01-03T00:00:00Z"
date_end = "2007-01-03T00:00:00Z"

import datetime
import dateutil.parser


def parse_date(date):
    """Parse date from ISO 8601 format to datetime
 
    Parameters:
        date (str): date in the format ISO 8601: 2001-01-15T14:56:00Z
        
    Returns:
        date (datetime): date parsed

    """
    return dateutil.parser.parse(date)


def days_between_dates(start, end):
    date =  parse_date(end) - parse_date(start)
    return date.days

days_between_dates(date_end, date_start)
